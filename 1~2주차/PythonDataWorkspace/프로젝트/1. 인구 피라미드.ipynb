# %%
import pandas as pd
file_name = '202207_202207_연령별인구현황_월간.xlsx'
df_m = pd.read_excel(file_name, skiprows=3, index_col='행정기관', usecols='B,E:Y')
df_m.head(3)
# Out:
# C:\Users\GSENR\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#             0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국       749,841  1,107,540  1,219,290  1,202,991  1,574,862  1,849,111
# 서울특별시    120,802    167,636    188,149    196,635    280,562    395,964
# 부산광역시     42,859     65,865     68,969     67,471     96,477    112,671
#
#             30~34세     35~39세     40~44세     45~49세  ...     55~59세  \
# 행정기관                                                 ...
# 전국       1,709,036  1,730,919  2,056,036  2,075,063  ...  2,080,415
# 서울특별시      374,091    340,614    365,779    360,988  ...    345,221
# 부산광역시      102,315    103,084    127,904    124,062  ...    129,692
#
#             60~64세     65~69세     70~74세   75~79세   80~84세   85~89세  90~94세  \
# 행정기관
# 전국       2,076,608  1,493,177  1,024,795  708,641  486,186  205,653  52,342
# 서울특별시      345,225    265,132    187,512  136,368   89,629   34,920   9,269
# 부산광역시      143,818    116,230     82,624   55,362   35,112   12,904   3,024
#
#         95~99세 100세 이상
# 행정기관
# 전국       9,173   1,558
# 서울특별시    1,858     431
# 부산광역시      452      88
#
# [3 rows x 21 columns]

# %%
df_m.iloc[0] = df_m.iloc[0].str.replace(',', '').astype(int)

# %%
df_m.iloc[0]
# Out:
# 0~4세        749841
# 5~9세       1107540
# 10~14세     1219290
# 15~19세     1202991
# 20~24세     1574862
# 25~29세     1849111
# 30~34세     1709036
# 35~39세     1730919
# 40~44세     2056036
# 45~49세     2075063
# 50~54세     2295413
# 55~59세     2080415
# 60~64세     2076608
# 65~69세     1493177
# 70~74세     1024795
# 75~79세      708641
# 80~84세      486186
# 85~89세      205653
# 90~94세       52342
# 95~99세        9173
# 100세 이상       1558
# Name: 전국  , dtype: object

# %%
df_w = pd.read_excel(file_name, skiprows=3, index_col='행정기관', usecols='B,AB:AV')
df_w.head(3)
# Out:
# C:\Users\GSENR\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#           0~4세.1     5~9세.1   10~14세.1   15~19세.1   20~24세.1   25~29세.1  \
# 행정기관
# 전국       712,701  1,054,599  1,151,492  1,122,994  1,450,305  1,657,358
# 서울특별시    113,210    160,003    178,144    189,202    313,966    420,950
# 부산광역시     40,725     62,511     65,495     63,309     91,486    103,830
#
#           30~34세.1   35~39세.1   40~44세.1   45~49세.1  ...   55~59세.1  \
# 행정기관                                                 ...
# 전국       1,561,059  1,645,989  1,987,428  2,016,185  ...  2,032,257
# 서울특별시      374,401    341,409    371,734    370,287  ...    356,931
# 부산광역시       95,589     99,146    124,322    123,004  ...    138,095
#
#           60~64세.1   65~69세.1   70~74세.1 75~79세.1 80~84세.1 85~89세.1 90~94세.1  \
# 행정기관
# 전국       2,117,518  1,592,318  1,161,257  913,171  774,599  451,696  172,735
# 서울특별시      378,063    303,339    220,222  168,853  122,469   64,981   25,305
# 부산광역시      160,275    131,561     97,864   69,675   53,994   27,938   10,225
#
#         95~99세.1 100세 이상.1
# 행정기관
# 전국        39,353     6,975
# 서울특별시      6,351     1,312
# 부산광역시      2,278       346
#
# [3 rows x 21 columns]

# %%
df_m.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.columns
# Out:
# Index(['0~4세.1', '5~9세.1', '10~14세.1', '15~19세.1', '20~24세.1', '25~29세.1',
#        '30~34세.1', '35~39세.1', '40~44세.1', '45~49세.1', '50~54세.1', '55~59세.1',
#        '60~64세.1', '65~69세.1', '70~74세.1', '75~79세.1', '80~84세.1', '85~89세.1',
#        '90~94세.1', '95~99세.1', '100세 이상.1'],
#       dtype='object')

# %%
df_w.columns = df_m.columns
df_w.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.iloc[0] = df_w.iloc[0].str.replace(',', '').astype(int)

# %%
df_w
# Out:
#               0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국          712701  1054599  1151492  1122994  1450305  1657358  1561059
# 서울특별시      113,210  160,003  178,144  189,202  313,966  420,950  374,401
# 부산광역시       40,725   62,511   65,495   63,309   91,486  103,830   95,589
# 대구광역시       30,624   48,262   52,001   52,621   68,608   73,004   64,002
# 인천광역시       41,833   61,427   67,025   64,718   83,162  100,569   95,690
# 광주광역시       21,229   32,126   36,180   36,619   47,464   49,119   41,578
# 대전광역시       20,461   30,309   33,448   34,328   47,102   50,943   44,284
# 울산광역시       16,775   26,045   27,259   24,703   27,482   30,442   30,623
# 세종특별자치시      9,643   13,291   13,389   10,291    8,556   10,399   14,077
# 경기도        212,047  307,916  330,518  314,611  390,425  444,021  437,161
# 강원도         20,254   27,670   31,601   32,093   38,113   37,314   36,075
# 충청북도        22,283   32,688   35,767   34,436   40,850   43,889   40,798
# 충청남도        30,699   45,634   49,962   46,940   51,690   52,479   54,151
# 전라북도        21,467   34,137   40,397   40,681   47,414   44,863   40,019
# 전라남도        23,513   34,521   39,617   38,481   42,367   40,865   37,869
# 경상북도        33,045   49,687   53,400   51,230   57,715   57,485   57,571
# 경상남도        44,123   71,751   79,561   72,664   76,214   77,741   78,999
# 제주특별자치도     10,770   16,621   17,728   16,067   17,691   19,445   18,172
#
#             35~39세   40~44세   45~49세  ...   55~59세   60~64세   65~69세   70~74세  \
# 행정기관                                  ...
# 전국         1645989  1987428  2016185  ...  2032257  2117518  1592318  1161257
# 서울특별시      341,409  371,734  370,287  ...  356,931  378,063  303,339  220,222
# 부산광역시       99,146  124,322  123,004  ...  138,095  160,275  131,561   97,864
# 대구광역시       68,974   89,690   96,557  ...  102,194  102,840   78,587   59,441
# 인천광역시       98,146  118,099  117,073  ...  124,047  122,798   84,394   56,252
# 광주광역시       45,330   58,102   60,160  ...   55,311   53,459   37,637   30,276
# 대전광역시       45,034   55,925   59,138  ...   55,118   57,777   42,066   29,350
# 울산광역시       35,170   44,613   44,513  ...   48,673   46,794   32,393   20,599
# 세종특별자치시     17,368   20,768   16,844  ...   10,408   10,259    7,301    4,758
# 경기도        469,264  565,615  560,978  ...  524,443  505,571  353,344  241,189
# 강원도         39,843   51,376   55,497  ...   63,785   75,058   56,638   39,082
# 충청북도        45,992   55,737   58,779  ...   63,516   69,752   52,463   36,044
# 충청남도        62,981   76,172   77,008  ...   77,196   86,057   65,849   51,902
# 전라북도        45,942   59,284   66,003  ...   70,139   77,050   59,886   50,820
# 전라남도        44,843   56,573   60,849  ...   72,484   80,509   61,470   55,035
# 경상북도        68,651   86,554   92,889  ...  108,900  121,475   98,033   75,427
# 경상남도        96,329  125,492  129,378  ...  134,937  144,580  108,711   79,358
# 제주특별자치도     21,567   27,372   27,228  ...   26,080   25,201   18,646   13,638
#
#             75~79세   80~84세  85~89세  90~94세 95~99세 100세 이상
# 행정기관
# 전국          913171   774599  451696  172735  39353    6975
# 서울특별시      168,853  122,469  64,981  25,305  6,351   1,312
# 부산광역시       69,675   53,994  27,938  10,225  2,278     346
# 대구광역시       43,060   35,786  19,572   6,880  1,378     233
# 인천광역시       44,083   35,272  20,773   8,489  2,065     346
# 광주광역시       22,934   18,438  10,141   3,928    891     170
# 대전광역시       21,984   18,162  10,465   4,031    885     150
# 울산광역시       13,588   10,514   6,031   2,209    522      59
# 세종특별자치시      3,444    3,039   2,095     898    180      23
# 경기도        192,830  155,619  90,717  35,205  8,373   1,494
# 강원도         35,870   32,806  18,292   7,424  1,836     283
# 충청북도        30,634   28,838  18,093   6,339  1,391     240
# 충청남도        41,656   41,736  27,819  10,398  2,235     396
# 전라북도        42,495   40,697  25,492   9,844  2,087     380
# 전라남도        49,941   50,714  30,298  11,791  2,574     484
# 경상북도        59,792   59,834  37,282  13,721  2,934     508
# 경상남도        60,762   56,644  34,889  13,164  2,611     349
# 제주특별자치도     11,570   10,037   6,818   2,884    762     202
#
# [18 rows x 21 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
plt.figure(figsize = (10,7))
plt.barh(df_m.columns, -df_m.iloc[0] // 1000)
plt.barh(df_w.columns, df_w.iloc[0] // 1000)
plt.title('2022 대한민국 인구 피라미드')
plt.savefig("2022_인구피라미드.png", dpi=100)
plt.show()
