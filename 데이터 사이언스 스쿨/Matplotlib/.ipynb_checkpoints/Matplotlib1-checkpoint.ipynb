# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
plt.title('Plot')
plt.plot([1,4,9.16])
plt.grid(True)
plt.show()

# %%
plt.title("x tick")
plt.plot([10,20,30,40], [1,4,9,16])
plt.show()

# %%
plt.title("'rs--' style plot ")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], c = 'b',lw= 5 ,ls = "--",marker='o', ms = '15',mec = "g", mew=5,mfc='r' )
plt.xlim(0, 50)
plt.ylim(-10,30)
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)
plt.title("x & y tick label set")
plt.plot(X, C)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
plt.yticks([-1, 0, +1])
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)
plt.title("LaTeX, tick label define")
plt.plot(X, C)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi],
           [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, 1], ["Low", "Zero", "High"])
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)
plt.title("Grid")
plt.plot(X, C)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi],
           [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, 1], ["Low", "Zero", "High"])
plt.show()

# %%
t = np.arange(0., 5., 0.2)
plt.title("Multi lines")
plt.plot(t, t, 'r--', t, 0.5 * t**2, 'bs:', t, 0.2 * t**3, 'g^-')
plt.show()

# %%
plt.title("Plots")
plt.plot([1,4,9,16], c = "b", lw=5, ls='--', marker = 'o', ms='15', mec='g', mew=5, mfc='r')
plt.plot([9, 16, 4, 1], c="k", lw=3, ls=":", marker="s", ms=10, mec="m", mew=5, mfc="c")
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.title("legend")
plt.plot(X, C, ls="--", label="cosine")
plt.plot(X, S, ls=":", label="sine")
plt.legend(loc = 2)
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.title("Cosine Plot")
plt.plot(X, C, label="cosine")
plt.xlabel("time")
plt.ylabel("amplitude")
plt.show()

# %%
x = np.linspace(-np.pi,np.pi,100)
c, s, t = np.cos(x), np.sin(x), np.tan(x)
y = np.arange(0.1, 10.1, 0.1)
plt.title="P"
plt.plot(x, c , c='b',ls = '--', lw=3, marker='+', ms=.05, mec = 'm', mew=.5, mfc = 'y', label = 'Cosine')
plt.plot(x, s , c='r',ls = '-.', lw=3, marker='h', ms=.05, mec = 'g', mew=.5, mfc = 'b', label = 'Sine')
#plt.plot(x, t , c='y',ls = ':', lw=3, marker='o', ms=5, mec = 'c', mew=5, mfc = 'b', label = 'Tangent')
plt.plot(x, y, label = 'Single')
plt.legend(loc= 0)

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.plot(X, C, label="cosine")
plt.xlabel("time")
plt.ylabel("amplitude")
plt.title("Cosine Plot")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 6>()
#       4 plt.xlabel("time")
#       5 plt.ylabel("amplitude")
# ----> 6 plt.title("Cosine Plot")
#       7 plt.show()
#
# TypeError: 'str' object is not callable

# %%
np.random.seed(0)
f1 = plt.figure(figsize=(10, 2))
#plt.title("figure size : (10, 2)")
plt.plot(np.random.randn(100))
plt.show()

# %%
f1 = plt.figure(1)
#plt.title("figure")
plt.plot([1, 2, 3, 4], 'ro:')

f2 = plt.gcf()
print(f1, id(f1))
print(f2, id(f2))
plt.show()

# %%
subplot(2, 1, 1)
# 여기에서 윗부분에 그릴 플롯 명령 실행
subplot(2, 1, 2)
# 여기에서 아랫부분에 그릴 플롯 명령 실행

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

ax1 = plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

ax2 = plt.subplot(2, 1, 2)
plt.plot(x2, y2, 'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.tight_layout()
plt.show()

# %%
np.random.seed(0)

plt.subplot(221)
plt.plot(np.random.rand(5))
plt.title("axes 1")

plt.subplot(222)
plt.plot(np.random.rand(5))
plt.title("axes 2")

plt.subplot(223)
plt.plot(np.random.rand(5))
plt.title("axes 3")

plt.subplot(224)
plt.plot(np.random.rand(5))
plt.title("axes 4")

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 5>()
#       3 plt.subplot(221)
#       4 plt.plot(np.random.rand(5))
# ----> 5 plt.title("axes 1")
#       7 plt.subplot(222)
#       8 plt.plot(np.random.rand(5))
#
# TypeError: 'str' object is not callable

# %%
fig, axes = plt.subplots(2, 2)

np.random.seed(0)
axes[0, 0].plot(np.random.rand(5))
axes[0, 0].set_title("axes 1")
axes[0, 1].plot(np.random.rand(5))
axes[0, 1].set_title("axes 2")
axes[1, 0].plot(np.random.rand(5))
axes[1, 0].set_title("axes 3")
axes[1, 1].plot(np.random.rand(5))
axes[1, 1].set_title("axes 4")

plt.tight_layout()
plt.show()

# %%
fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title("2개의 y축 한 figure에서 사용하기")
ax0.plot([10, 5, 2, 9, 7], 'r-', label="y0")
ax0.set_ylabel("y0")
ax0.grid(False)
ax1.plot([100, 200, 220, 180, 120], 'g:', label="y1")
ax1.set_ylabel("y1")
ax1.grid(False)
ax0.set_xlabel("공유되는 x축")
plt.show()
# Out:
# C:\Users\GSENR\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44060 (\N{HANGUL SYLLABLE GAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\GSENR\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\GSENR\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 52629 (\N{HANGUL SYLLABLE CUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\GSENR\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\GSENR\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50640 (\N{HANGUL SYLLABLE E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
